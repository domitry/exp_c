# %%
gem 'nyaplot', '0.1.5'
# Out:
# false

# %%
require 'nyaplot'
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\n\t};\n\n\n});});\n}\n"
# true

# %%
include Nyaplot
# Out:
# Object

# %%
def plot_line(fname)
    x_arr = []
    y_arr = []
    File.read(fname).split("\n").each do |str|
        a, b = str.split(" ").map{|s| s.to_f} 
        x_arr.push(a)
        y_arr.push(b)
    end
    p = Plot.new
    p.add(:line, x_arr, y_arr)
    p
end
# Out:
# :plot_line

# %%
plot_line("/home/naoki/exp_c/compiled/42series_given_noise.dat")
# Out:
# #<Nyaplot::Plot:0x00000001863a70 @properties={:diagrams=>[#<Nyaplot::Diagram:0x00000001757258 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"1ef1f512-c397-455e-b948-27263cc837b3"}, @xrange=[0.0, 511.0], @yrange=[-1.0, 1.0]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 511.0], :yrange=>[-1.0, 1.0]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/42rev_dfted.dat")
# Out:
# #<Nyaplot::Plot:0x00000001b9b828 @properties={:diagrams=>[#<Nyaplot::Diagram:0x00000001b39038 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"e397892c-85cb-43f0-820b-bf37562b60be"}, @xrange=[0.0, 511.0], @yrange=[-1.0, 1.0]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 511.0], :yrange=>[-1.0, 1.0]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/42_real_part.dat")
# Out:
# #<Nyaplot::Plot:0x0000000252e4a8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x0000000255f968 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"c434b43e-55d0-4cae-8608-d6ab423ad7a5"}, @xrange=[0.0, 511.0], @yrange=[-0.000471, 0.0]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 511.0], :yrange=>[-0.000471, 0.0]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/42_imaginary_part.dat")
# Out:
# #<Nyaplot::Plot:0x000000016a0468 @properties={:diagrams=>[#<Nyaplot::Diagram:0x000000015ac3e0 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"dc110657-3ccd-4d35-a36d-49adec308359"}, @xrange=[0.0, 511.0], @yrange=[-256.0, 255.999925]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 511.0], :yrange=>[-256.0, 255.999925]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/42re_dfted.dat")
# Out:
# #<Nyaplot::Plot:0x000000017042d8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x000000015df1a0 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"8088e033-4442-4421-a8cd-8d957fd71f0b"}, @xrange=[0.0, 511.0], @yrange=[-511.999897, 511.999897]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 511.0], :yrange=>[-511.999897, 511.999897]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/42error.dat")
# Out:
# #<Nyaplot::Plot:0x00000001c79970 @properties={:diagrams=>[#<Nyaplot::Diagram:0x00000001a51418 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"31aff2c7-df46-4398-b85d-216e5c3cd133"}, @xrange=[0.0, 511.0], @yrange=[-1.0e-06, 1.0e-06]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 511.0], :yrange=>[-1.0e-06, 1.0e-06]}}>
