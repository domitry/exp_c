# %%
gem 'nyaplot', '0.1.5'
# Out:
# true

# %%
require 'nyaplot'
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\n\t};\n\n\n});});\n}\n"
# true

# %%
include Nyaplot
# Out:
# Object

# %%
def plot_line(fname)
    x_arr = []
    y_arr = []
    File.read(fname).split("\n").each do |str|
        a, b = str.split(" ").map{|s| s.to_f} 
        x_arr.push(a)
        y_arr.push(b)
    end
    p = Plot.new
    p.add(:line, x_arr, y_arr)
    p
end
# Out:
# :plot_line

# %%
plot_line("/home/naoki/exp_c/compiled/36sin_with_noise.dat")
# Out:
# #<Nyaplot::Plot:0x00000003585928 @properties={:diagrams=>[#<Nyaplot::Diagram:0x000000034495a0 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"f83aaa38-0fb7-48a3-b93a-4abcaac32c60"}, @xrange=[0.0, 6.270913], @yrange=[-1.155766, 1.160379]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 6.270913], :yrange=>[-1.155766, 1.160379]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/34sin.dat")
# Out:
# #<Nyaplot::Plot:0x0000000332acc8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x00000003878c70 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"7f7d6423-c334-4905-ac68-acd1c39aa2e7"}, @xrange=[0.0, 6.270913], @yrange=[-1.0, 1.0]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 6.270913], :yrange=>[-1.0, 1.0]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/37impulse.dat")
# Out:
# #<Nyaplot::Plot:0x000000037e5f10 @properties={:diagrams=>[#<Nyaplot::Diagram:0x0000000378ba88 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"bb3651f8-da82-47c8-b986-06012fc4b847"}, @xrange=[0.0, 6.270913], @yrange=[-4.971582, 31.415927]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 6.270913], :yrange=>[-4.971582, 31.415927]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/37impulse5.dat")
# Out:
# #<Nyaplot::Plot:0x000000027cd3a8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x00000002612810 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"4684cd91-0915-440c-9f84-704e60e5f746"}, @xrange=[0.0, 6.270913], @yrange=[-171.629614, 1570796.32499]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 6.270913], :yrange=>[-171.629614, 1570796.32499]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/38series10.dat")
# Out:
# #<Nyaplot::Plot:0x00000002566ad8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x00000002440190 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"fb5059ec-25fb-4413-b77f-ef6e3563baf4"}, @xrange=[0.0, 6.270913], @yrange=[-0.016551, 1.500049]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 6.270913], :yrange=>[-0.016551, 1.500049]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/38series100.dat")
# Out:
# #<Nyaplot::Plot:0x0000000361ff50 @properties={:diagrams=>[#<Nyaplot::Diagram:0x00000003709420 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"09e32100-dba5-4d86-bed4-dd6d5adbee66"}, @xrange=[0.0, 6.270913], @yrange=[-0.000906, 1.564431]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 6.270913], :yrange=>[-0.000906, 1.564431]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/38series1000.dat")
# Out:
# #<Nyaplot::Plot:0x000000038df380 @properties={:diagrams=>[#<Nyaplot::Diagram:0x000000038f7a20 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"2905fbc5-7275-4f82-9458-7a8338f7c3cd"}, @xrange=[0.0, 6.270913], @yrange=[-1.0e-06, 1.57016]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0.0, 6.270913], :yrange=>[-1.0e-06, 1.57016]}}>

# %%
plot_line("/home/naoki/exp_c/compiled/39error.dat")
# Out:
# #<Nyaplot::Plot:0x00000003480460 @properties={:diagrams=>[#<Nyaplot::Diagram:0x00000003478508 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"73cf6348-44e9-4a44-a664-3afb4af3c2b0"}, @xrange=[10.0, 990.0], @yrange=[-0.00418, 0.000495]>], :options=>{:zoom=>true, :width=>700, :xrange=>[10.0, 990.0], :yrange=>[-0.00418, 0.000495]}}>

# %%
{
